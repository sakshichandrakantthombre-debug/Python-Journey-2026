# %%
#Take name from user and input print it

name=str(input("Enter the name"))
print(name)
# Out:
# Enter the name sakshi
# sakshi

# %%
#Take two number and print sum

a=6
b=10
sum=a+b
print(sum)
# Out:
# 16

# %%
#calculate the totle marks:
a=70
b=90
c=60
totle=a+b+c
print("totle marks =", totle)
# Out:
# totle marks = 220

# %%
#findest highest marks student
Marks=[50, 90, 89]
print("Highest Marks =", max(Marks))
# Out:
# Highest Marks = 90

# %%
#findest lowest marks student
marks=(input("marathi"));
marks=(input("math"));
marks=(input("english"));
print("higest marks =", min(marks))
# Out:
# marathi 7
# math 9
# english 8
# higest marks = 8

# %%
#Make mark grade percentage through :
total = int(input("Enter total marks: "))
percentage = total / 3

if percentage >= 75:
    print("Grade A")
elif percentage >= 50:
    print("Grade B")
else:
    print("Grade C")
# Out:
# Enter total marks:  90
# Grade C

# %%
# print the total and average marks of sub:
math=85
science=85
english=78
total=math+science+english
average=totle/3
print("total marks:", total)
print("average:", average)
# Out:
# total marks: 248
# average: 73.33333333333333

# %%
#print the area of circle
a=7
b=9
area_rectangle=a*b
print("area of rectangle", area_rectangle)
# Out:
# area of rectangle 63

# %%
# calculate the average of the user given number:
num1=int(input("enter a number"))
num2=int(input("enter a number"))
totle=num1+num2
average=totle/2
print(totle)
print(average)
# Out:
# enter a number 9
# enter a number 7
# 16
# 8.0

# %%
# calculate the area of circle given input:
a=8
b=5
area_circle=0.5*a*b
print("area of circle"  ,area_circle)
# Out:
# area of circle 20.0
