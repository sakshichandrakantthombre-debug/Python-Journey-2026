# %%
#print the below the list:
n1=[20, 30, 40, 60]
print(n1)
# Out:
# [20, 30, 40, 60]

# %%
#print the length of the below list:
n1=[2, 4, 5, 6, 7, 8]
print(len(n1))
# Out:
# 6

# %%
print the given index decided value:
n1=[10, 20, 'jessa', 12.50, 'Emma']
print(n1[3])
# Out:
# 12.5

# %%
#print the slicing of the list:
n1= [10, 20, 'sham', 12.5, 'Emma', 25, 50]
print(n1[2:4])
# Out:
# ['sham', 12.5]

# %%
#slicing  of the given iteam list:
n1= [10, 20, 'sham', 12.5, 'Emma', 25, 50]
print(n1[::2])
# Out:
# [10, 'sham', 'Emma', 50]

# %%
# print the reversing the list:
n1= [10, 20, 'sham', 12.5, 'Emma', 25, 50]
print(n1[::-1])
# Out:
# [50, 25, 'Emma', 12.5, 'sham', 20, 10]

# %%
#slice first last three items:
n1= [10, 20, 'sham', 12.5, 'Emma', 25, 50]
print(n1[3::])
# Out:
# [12.5, 'Emma', 25, 50]

# %%
#print the iterate the list
n1= [10, 20, 'sham', 12.5, 'Emma', 25, 50]
for item in range (0, len(n1)):
    print(item)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
#append item at the end of the list:
n1= [10, 20, 'sham', 12.5, 25, 50]
n1.append('Emma')
print(n1)
# Out:
# [10, 20, 'sham', 12.5, 25, 50, 'Emma']

# %%
n1.append([25, 50, 75])
print(n1)
# Out:
# [10, 20, 'sham', 12.5, 25, 50, 'Emma', [25, 50, 75]]

# %%
#add item a specific position:
n1= list([10, 20, 'sham', 12.5, 25, 50])
n1.insert(3,[9])
print(n1)
n1.insert(3, [25, 50, 75])
print(n1)
# Out:
# [10, 20, 'sham', [9], 12.5, 25, 50]
# [10, 20, 'sham', [25, 50, 75], [9], 12.5, 25, 50]

# %%
# add three item at the end of list>
n1= list([5, 8, 'tom' , 7.50])
n1.extend([1, 2, 3])
print(n1)
# Out:
# [5, 8, 'tom', 7.5, 1, 2, 3]

# %%
# modify the single iteam below the list:
n1= list([5, 8, 'tom' , 7.50])
n1[0]=20
print(n1)
n1[1] =40
print(n1)
# Out:
# [20, 8, 'tom', 7.5]
# [20, 40, 'tom', 7.5]
