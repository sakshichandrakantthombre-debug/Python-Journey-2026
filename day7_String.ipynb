# %%
# program: find length of a string:
text = input("Enter  a string: ")
print("length if the string is:",len(text))
# Out:
# Enter  a string:  sakshi
# length if the string is: 6

# %%
# first and last character :
text = input("Enter  a string: ")
print("first character:" ,text[0])
print("Last character:" ,text[-1])
# Out:
# Enter  a string:  pune
# first character: p
# Last character: e

# %%
#Reverse  a string:
text=input("Enter the string:")
print("Reversed string:" ,text[::-1])
# Out:
# Enter the string: sakshi
# Reversed string: ihskas

# %%
#count vowels
text= input("enter  the a string:")
text.lower()
# Out:
# enter  the a string: SAKSHI
# 'sakshi'

# %%
ch= "sakshi"
ch.isalpha()
# Out:
# True

# %%
# count spaces:
text=input("Enter the string:")
print(text.upper())
# Out:
# Enter the string: sakshi
# SAKSHI

# %%
# capitalize
text= input("Enter a string:")
print(text.title())
# Out:
# Enter a string: pune
# Pune

# %%
#swapcase
text=input("Enter the string: ")
print(text.swapcase())
# Out:
# Enter the string:  maharashtra
# MAHARASHTRA

# %%
#strip
text=input("enter the string:")
print(text.strip())
# Out:
# enter the string: " swami "
# " swami "

# %%
# replace
text= input("Enter the string: ")
print(text.replace("a", "@"))
# Out:
# Enter the string:  gmaila
# gm@il@

# %%
#split
text=input("enter the a sentences: ")
print(text.split())
# Out:
# enter the a sentences:  doughter
# ['doughter']

# %%
# join()
words= ["Python", "is", "easy"]
print(" ".join(words))
# Out:
# Python is easy

# %%
# find()
text= input("Enter the string: ")
print(text.find("a"))
# Out:
# Enter the string:  "I am a girls"
# 3

# %%
# startwith:
text=input("Enter the  a string: ")
print(text.startswith("p"))
# Out:
# Enter the  a string:  pop
# True

# %%
# isolpha:
text= input("Enter the string: ")
print(text.endswith("n"))
# Out:
# Enter the string:  banana
# False

# %%
#isdigit()
text= input("Enter the a string:")
print(text.isdigit())
# Out:
# Enter the a string: 8
# True

# %%
#isalnum()
text=input("Enter the a string:")
print(text.isalnum())
# Out:
# Enter the a string: pune123
# True

# %%
#isspace()
text=input("Enter the a string: ")
print(text.isspace())
